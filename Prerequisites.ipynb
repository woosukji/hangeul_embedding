# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FOLDERNAME = 'ML/KRembedding/'

LIB_PATH = 'lib'

# %cd drive/My\ Drive/$FOLDERNAME
# %mkdir $LIB_PATH
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/CS/KRembedding

# %%
# %pip install --target=$LIB_PATH --ignore-installed --upgrade --quiet konlpy soynlp sentencepiece Jpype1
# Out:
#      |████████████████████████████████| 19.4MB 1.2MB/s
#      |████████████████████████████████| 419kB 42.2MB/s
#      |████████████████████████████████| 460kB 36.5MB/s
#      |████████████████████████████████| 92kB 10.8MB/s
#      |████████████████████████████████| 15.3MB 290kB/s
#      |████████████████████████████████| 6.3MB 21.9MB/s
#      |████████████████████████████████| 296kB 59.1MB/s
#      |████████████████████████████████| 22.3MB 39.0MB/s
#      |████████████████████████████████| 27.4MB 99kB/s
#      |████████████████████████████████| 61kB 7.6MB/s
#      |████████████████████████████████| 307kB 50.5MB/s
#      |████████████████████████████████| 153kB 52.3MB/s
#      |████████████████████████████████| 153kB 49.5MB/s
#      |████████████████████████████████| 61kB 8.1MB/s
#      |████████████████████████████████| 184kB 62.0MB/s
#      |████████████████████████████████| 153kB 58.5MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FOLDERNAME = 'ML/KRembedding/'

LIB_PATH = 'lib'

# %cd drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/ML/KRembedding

# %%
# !git init
# !git config --global user.email "woosukji@snu.ac.kr"
# !git config --global user.name "woosukji"

# %%
# !git add .

# %%
# !git commit -m 'docs: write explanation for ch03-02'
# Out:
# [main 63c74f1] docs: write explanation for ch03-02
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite ch03/03-02 Supervised Tokenizer.ipynb (95%)

# %%
# !git push origin main
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 16.21 KiB | 2.03 MiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/woosukji/hangeul_embedding.git
#    1fc2b61..0e7263c  main -> main
